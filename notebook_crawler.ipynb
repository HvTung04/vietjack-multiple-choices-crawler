# %%
from utils import utils
from crawler.crawler import Crawler
import random
import os

# %%
import os.path
import csv

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# %%
def create_and_write_to_sheet(service, spreadsheet_id, sheet_name, csv_file):
    # Create sheet
    batch_update_values_request_body = {
        "requests": [{"addSheet": {"properties": {"title": sheet_name}}}]
    }
    request = service.spreadsheets().batchUpdate(
        spreadsheetId=spreadsheet_id, body=batch_update_values_request_body
    )
    response = request.execute()

    f = open(csv_file, "r", encoding="utf-8")
    values = [r for r in csv.reader(f)]
    request = (
        service.spreadsheets()
        .values()
        .update(
            spreadsheetId=spreadsheet_id,
            range=sheet_name,
            valueInputOption="USER_ENTERED",
            body={"values": values},
        )
        .execute()
    )

# %%
SCOPES = ["https://www.googleapis.com/auth/spreadsheets"]

SPREADSHEET_ID = "1xnwcV6J6NSokWHDzxw1MEFAHS39j-v-U_4uKa6OixgY"

creds = None
if os.path.exists("token.json"):
    creds = Credentials.from_authorized_user_file("token.json", SCOPES)
# If there are no (valid) credentials available, let the user log in.
if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
        creds.refresh(Request())
else:
    flow = InstalledAppFlow.from_client_secrets_file("credentials.json", SCOPES)
    creds = flow.run_local_server(port=0)
    # Save the credentials for the next run
    with open("token.json", "w") as token:
        token.write(creds.to_json())

try:
    service = build("sheets", "v4", credentials=creds)
except HttpError as err:
    print(err)

# %%
# Get all the answer page hrefs from the main page
hrefs = utils.export_all_href(
    "https://www.vietjack.com/bai-tap-trac-nghiem-giai-tich-12/",
    "vietjack_com"
)

# %%
for href in hrefs:
    list_model = [
        "llama3-8b-8192",
        "llama-3.1-8b-instant",
        "llama3-70b-8192",
    ]  # Groq's model to use
    model_name = random.choice(list_model)

    path = f"crawl_result/giaitich12/{href.split('/')[-1][:-4]}.csv"
    if os.path.exists(path):
        print(f"Existed! Skipping {path}.....")
        continue
    print(f"Using model {model_name} to crawl {path}")
    crawler = Crawler(url_list=[href], model_name=model_name, site="vietjack_com")
    crawler.crawl()
    crawler.save(path)
    try:
        create_and_write_to_sheet(
            service, SPREADSHEET_ID, href.split('/')[-1][:-4], path
        )
    except HttpError as err:
        print(err)
# Out:
# Existed! Skipping crawl_result/giaitich12/bai-tap-trac-nghiem-su-dong-bien-nghich-bien-cua-ham-so-phan-1.csv.....
# Using model llama3-70b-8192 to crawl crawl_result/giaitich12/bai-tap-trac-nghiem-su-dong-bien-nghich-bien-cua-ham-so-phan-2.csv
# Getting all questions from the given urls...
# Getting questions from https://vietjack.com/../bai-tap-trac-nghiem-giai-tich-12/bai-tap-trac-nghiem-su-dong-bien-nghich-bien-cua-ham-so-phan-2.jsp...
# Error fetching question: list index out of range
# --------------ERROR-------------------
# Question tag: <p style="color:green;"><b>Câu 12:</b> Hỏi hàm số </p>
# Choices tags: []
# ---------------------------------
#
#
# Error fetching question: list index out of range
# --------------ERROR-------------------
# Question tag: <p style="color:green;"><b>Câu 18:</b> Cho hàm số y = x<sup>3</sup> - x<sup>2</sup> + (m-1)x + m. Tìm điều kiện của tham số m để hàm số đồng biến trên R</p>
# Choices tags: [<p><img alt="Bài tập trắc nghiệm Giải tích 12 | Câu hỏi trắc nghiệm Giải tích 12" src="../bai-tap-trac-nghiem-giai-tich-12/images/bai-tap-trac-nghiem-su-dong-bien-nghich-bien-cua-ham-so-phan-4-thuysin-73.PNG" style="display: inline;"/>
# </p>]
# ---------------------------------
#
#
# Got 8 questions from https://vietjack.com/../bai-tap-trac-nghiem-giai-tich-12/bai-tap-trac-nghiem-su-dong-bien-nghich-bien-cua-ham-so-phan-2.jsp.
# Reformatting all questions...
# ------------------ADDED-------------------
# {'question': 'Tìm khoảng đồng biến của hàm số y = 2x^3 - 9x^2 + 12x + 3', 'A': '(-∞; 1) ∪ (2; +∞)', 'B': '(-∞; 1] và [2; +∞)', 'C': '(-∞; 1) và (2; +∞)', 'D': '(1;2)', 'answer': 'A', 'reasoning': 'Hàm số đồng biến trên các khoảng (-∞; 1) và (2; +∞)'}
# ---------------------------------
#
#
# ------------------ADDED-------------------
# {'question': 'Khoảng nghịch biến của hàm số y = x^{4} - 2x^{2} - 1 là:', 'A': '(-∞; -1) và (0; 1)', 'B': '(-∞; 0) và (1; +∞)', 'C': '(-∞; -1) ∪ (0; 1)', 'D': '(0;1)', 'answer': 'C', 'reasoning': 'Hàm số nghịch biến trên các khoảng (-∞; -1) và (0; 1)'}
# ---------------------------------
#
#
# ------------------ADDED-------------------
# {'question': 'Cho hàm số', 'A': 'Hàm số (1) nghịch biến trên R\\{1}', 'B': 'Hàm số (1) nghịch biến trên (-∞; 1) và (1; +∞)', 'C': 'Hàm số (1) nghịch biến trên (-∞; 1) ∪ (1; +∞)', 'D': 'Hàm số (1) đồng biến trên (-∞; 1) và (1; +∞)', 'answer': 'B', 'reasoning': 'Hàm số nghịch biến trên các khoảng (-∞; 1) và (1; +∞)'}
# ---------------------------------
#
#
# ------------------ADDED-------------------
# {'question': 'Tìm khoảng đồng biến của hàm số f(x) = x + cos^2 x', 'A': 'R\\{0}', 'B': '(-∞; +∞)', 'C': '(-1; 1)', 'D': '(0; π)', 'answer': 'B', 'reasoning': "f'(x) = 1 - 2sinxcosx = sin^2 x + cos^2 x - 2.sinx.cosx = (sinx - cosx)^2 ≥ 0 ∀x ∈ R. Hàm số đồng biến trên khoảng (-∞; +∞)"}
# ---------------------------------
#
#
# ------------------ADDED-------------------
# {'question': 'Hàm số:', 'A': 'R', 'B': '(-∞; 0)', 'C': '(-1; 0)', 'D': '(0; +∞)', 'answer': 'A', 'reasoning': 'Hàm số đồng biến trên R'}
# ---------------------------------
#
#
# ------------------ADDED-------------------
# {'question': 'Cho hàm số', 'A': 'm < 2\\sqrt{2}', 'B': 'm \\geq -2\\sqrt{2}', 'C': 'm = 2\\sqrt{2}', 'D': '-2\\sqrt{2} \\leq m \\leq 2\\sqrt{2}', 'answer': 'C', 'reasoning': "Ta có y' = -x^2 - mx - 2. Hàm số nghịch biến trên khoảng (-∞; -1) nếu y' = x^2 - mx - 2 ≤ 0 trên khoảng (-∞; -1)"}
# ---------------------------------
#
#
# ------------------ADDED-------------------
# {'question': 'Tìm tất cả các giá trị của tham số m sao cho hàm số', 'A': '1 < m < 5', 'B': 'm ≥ 5', 'C': 'm < -1 hoặc m > 5', 'D': 'm > 5', 'answer': 'C', 'reasoning': 'm < -1 hoặc m > 5'}
# ---------------------------------
#
#
# ------------------ADDED-------------------
# {'question': 'Cho hàm số y = x^3 + 3x^2 + mx + 1 - 2m. Tìm các giá trị của m để hàm số đồng biến trên đoạn có độ dài bằng 1.', 'A': 'm = 0', 'B': 'm = 1/4', 'C': '9/4', 'D': 'Không tồn tại', 'answer': 'D', 'reasoning': "y' = 3x^2 + 6x + m. Hàm số đồng biến nếu y' ≥ 0. Ta có Δ' = 9 - 3m. TH1: m ≥ 3 => Δ' ≤ 0. Hàm số đồng biến trên R. Do đó m ≥ 3 không thỏa mãn yêu cầu đề bài. TH2: m < 3 => Δ' > 0. y’ có hai nghiệm phân biệt là. Từ bảng biến thiên, ta thấy không tồn tại m để hàm số đồng biến trên đoạn có độ dài bằng 1. Từ TH1 và TH2, không tồn tại m thỏa mãn."}
# ---------------------------------
#
#
# Saved 8 questions to crawl_result/giaitich12/bai-tap-trac-nghiem-su-dong-bien-nghich-bien-cua-ham-so-phan-2.csv.
# <HttpError 400 when requesting https://sheets.googleapis.com/v4/spreadsheets/1xnwcV6J6NSokWHDzxw1MEFAHS39j-v-U_4uKa6OixgY:batchUpdate?alt=json returned "Invalid requests[0].addSheet: Đã tồn tại một trang tính có tên "bai-tap-trac-nghiem-su-dong-bien-nghich-bien-cua-ham-so-phan-2". Vui lòng nhập tên khác.". Details: "Invalid requests[0].addSheet: Đã tồn tại một trang tính có tên "bai-tap-trac-nghiem-su-dong-bien-nghich-bien-cua-ham-so-phan-2". Vui lòng nhập tên khác.">
# Using model llama3-70b-8192 to crawl crawl_result/giaitich12/bai-tap-trac-nghiem-cuc-tri-cua-ham-so-phan-1.csv
# Getting all questions from the given urls...
# Getting questions from https://vietjack.com/../bai-tap-trac-nghiem-giai-tich-12/bai-tap-trac-nghiem-cuc-tri-cua-ham-so-phan-1.jsp...
# Error fetching question: list index out of range
# --------------ERROR-------------------
# Question tag: <p style="color:green;"><b>Câu 2:</b> Cho hàm số y = f(x) xác định, liên tục trên R và có bảng biến thiên</p>
# Choices tags: []
# ---------------------------------
#
#
# Error fetching question: list index out of range
# --------------ERROR-------------------
# Question tag: <p style="color:green;"><b>Câu 3:</b> Tìm a, b, c sao cho hàm số y = x<sup>3</sup> + ax<sup>2</sup> + bx + c có giá trị bằng 0 khi x = 1  và đạt cực trị khi bằng 0 khi x = -1  .</p>
# Choices tags: []
# ---------------------------------
#
#
# Got 11 questions from https://vietjack.com/../bai-tap-trac-nghiem-giai-tich-12/bai-tap-trac-nghiem-cuc-tri-cua-ham-so-phan-1.jsp.
# Reformatting all questions...
# ------------------ADDED-------------------
# {'question': 'Trong các mệnh đề sau, mệnh đề nào đúng?', 'A': "Nếu $f'(x_0) = 0$ thì $x_0$ là điểm cực trị của hàm số.", 'B': "Nếu $f'(x_0) = 0$ thì $x_0$ là điểm cực đại của hàm số.", 'C': "Nếu $f'(x_0) = 0$ và $f''(x_0) > 0$ thì $x_0$ là điểm cực đại của hàm số.", 'D': 'Nếu $f(x)$ có đạo hàm tại $x_0$ và $f’(x)$ đổi dấu khi $x$ đi qua $x_0$ thì $x_0$ là điểm cực trị của hàm số.', 'answer': 'D', 'reasoning': 'Xem lại điều kiện cần và đủ để có cực trị của hàm số.'}
# ---------------------------------
#
#
# ------------------ADDED-------------------
# {'question': 'Tìm tất cả các giá trị của tham số m để hàm số y = x^3 - 2x^2 +mx + 1 đạt cực đại tại x = 1.', 'A': 'm = -1', 'B': 'm = 1', 'C': 'm = 4/3', 'D': 'Không tồn tại.', 'answer': 'D', 'reasoning': "Ta có y' = 3x^2 - 4x + m. Hàm số đạt cực trị tại x = 1 thì y'(1) = 0 ⇒ 3.1^2 - 4.1 + m = 0 ⇒ m = 1. Với m = 1 thì hàm số đã cho trở thành y = x^3 - 2x^2 + x + 1. Ta có y' = 3x^2 - 4x + 1, y'' = 6x - 4. Vì y''(1) = 2 > 0 nên hàm số đạt cực tiểu tại x = 1. Do vậy không có m thỏa mãn."}
# ---------------------------------
#
#
# ------------------ADDED-------------------
# {'question': 'Cho hàm số y = x^3 - 2x^2 + 3. Điểm M(0; 3)  là:', 'A': 'Cực đại của hàm số', 'B': 'Điểm cực đại của hàm số', 'C': 'Điểm cực đại của đồ thị hàm số', 'D': 'Điểm cực tiểu của đồ thị hàm số', 'answer': 'C', 'reasoning': "Ta có: y' = 3x^2 -4x; y'' = 6x - 4; y''(0) = -4 < 0. Do đó, điểm M(0;3) là điểm cực đại của đồ thị hàm số."}
# ---------------------------------
#
#
# ------------------ADDED-------------------
# {'question': 'Tìm điểm cực đại của hàm số y = \\sin^{2}x + \\sqrt{3}cosx + 1 với x ∈ (0; π)', 'A': 'x = 0', 'B': 'x = π', 'C': 'π/6', 'D': 'π/3', 'answer': 'C', 'reasoning': 'Ta có: ... (image description)'}
# ---------------------------------
#
#
# ------------------ADDED-------------------
# {'question': 'Có bao nhiêu mệnh đề đúng trong các phát biểu sau?', 'A': '0', 'B': '1', 'C': '2', 'D': '3', 'answer': 'C', 'reasoning': 'Do đó mệnh đề 1 và 4 đúng.'}
# ---------------------------------
#
#
# ------------------ADDED-------------------
# {'question': 'Cho hàm số y = -3x^4 - 2x^3 + 3', 'A': 'Một cực đại và hai cực tiểu', 'B': 'Một cực tiểu và hai cực đại', 'C': 'Một cực đại và không có cực tiểu', 'D': 'Một cực tiểu và một cực đại', 'answer': 'C', 'reasoning': "Ta có y' = -12x^3 - 6x. Xét y'=0 => x = 0. Hàm số chỉ có một cực đại tại x = 0."}
# ---------------------------------
#
#
# ------------------ADDED-------------------
# {'question': 'Cho hàm số  y = x^4 - 2(m - 1)x^2 + m^2. Tìm m để hàm số có 3 điểm cực trị là 3 đỉnh của 1 tam giác vuông', 'A': 'm = 0', 'B': 'm = 1', 'C': 'm = -1', 'D': 'm = 2', 'answer': 'A', 'reasoning': 'y = x^4 - 2(m - 1)x^2 + m^2'}
# ---------------------------------
#
#
# ------------------ADDED-------------------
# {'question': "Cho hàm số f có đạo hàm là f'(x) = x(x+1)^2(x-2)^4 với mọi x ∈ R. Số điểm cực trị của hàm số f là:", 'A': '0', 'B': '1', 'C': '2', 'D': '3', 'answer': 'A', 'reasoning': 'Dựa vào bảng biến thiên ta thấy hàm số đạt cực tiểu tại x = 0. Vậy hàm số có một cực trị'}
# ---------------------------------
#
#
# ------------------ADDED-------------------
# {'question': 'Điểm cực đại của hàm số y = -x^3 - 3x^2 + 1 là:', 'A': 'x = 0', 'B': 'x = -2', 'C': 'x = 2', 'D': 'Không tồn tại', 'answer': 'A', 'reasoning': "Ta có y' = -3x^2 - 6x, y'' = -6x - 6. Xét y''(0) = -6 < 0; y''(-2) = 6 > 0. Do đó hàm số đạt cực đại tại x = 0"}
# ---------------------------------
#
#
# ------------------ADDED-------------------
# {'question': 'Điểm cực tiểu của hàm số y = x^4 + 4x^2 + 2 là:', 'A': 'x = 1', 'B': 'x = √2', 'C': 'x = 0', 'D': 'Không tồn tại', 'answer': 'C', 'reasoning': "Ta có: y' = 4x^3 + 8x, y'' = 12x^2 + 8. y' = 0 <=> 4x(x^2 + 2) = 0 <=> x = 0. y''(0) = 2 > 0. Do đó hàm số đạt cực tiểu tại x = 0"}
# ---------------------------------
#
#
# ------------------ADDED-------------------
# {'question': 'Cho hàm số y = x^3 - 2x^2 - 1 và các mệnh đề', 'A': '0', 'B': '1', 'C': '2', 'D': '3', 'answer': 'D', 'reasoning': "Ta có: y' = 3x^2 - 4x, y'' = 6x - 4; y''(0) = -4 < 0; y''(4/3) = 4 > 0. Do đó hàm số có hai cực trị là x = 0 và x = 4/3. Các mệnh đề (1); (2) và (3) sai; mệnh đề (4) đúng."}
# ---------------------------------
#
#
# Saved 11 questions to crawl_result/giaitich12/bai-tap-trac-nghiem-cuc-tri-cua-ham-so-phan-1.csv.
# Using model llama3-70b-8192 to crawl crawl_result/giaitich12/bai-tap-trac-nghiem-cuc-tri-cua-ham-so-phan-2.csv
# Getting all questions from the given urls...
# Getting questions from https://vietjack.com/../bai-tap-trac-nghiem-giai-tich-12/bai-tap-trac-nghiem-cuc-tri-cua-ham-so-phan-2.jsp...
# Error fetching question: list index out of range
# --------------ERROR-------------------
# Question tag: <p style="color:green;"><b>Câu 16:</b> Hàm số y = cosx đạt cực trị tại những điểm</p>
# Choices tags: []
# ---------------------------------
#
#
# Error fetching question: list index out of range
# --------------ERROR-------------------
# Question tag: <p style="color:green;"><b>Câu 17:</b> Với giá trị nào của m, hàm số y = x<sup>3</sup> - 2x<sup>2</sup> + mx - 1 không có cực trị?</p>
# Choices tags: []
# ---------------------------------
#
#
# Error fetching question: list index out of range
# --------------ERROR-------------------
# Question tag: <p style="color:green;"><b>Câu 22:</b> Với giá trị nào của m, đồ thị hàm số y = x<sup>3</sup> - 3mx<sup>2</sup> + 3(m<sup>2</sup> - 1)x - m <sup>3</sup> + m có điểm cực đại B, điểm cực tiểu C thỏa mãn OC = 3OB, với O là gốc tọa độ?</p>
# Choices tags: []
# ---------------------------------
#
#
# Got 10 questions from https://vietjack.com/../bai-tap-trac-nghiem-giai-tich-12/bai-tap-trac-nghiem-cuc-tri-cua-ham-so-phan-2.jsp.
# Reformatting all questions...
# ------------------ADDED-------------------
# {'question': 'Với giá trị nào của m, hàm số y = -m x^4 + 2(m - 1)x^2 + 1 - 2m có một cực trị', 'A': '0 ≤ m ≤ 1', 'B': 'm > 1 hoặc m < 0', 'C': '0 < m < 1', 'D': '0 < m ≤ 1', 'answer': 'A', 'reasoning': "Xét hàm số y = -m x^4 +2(m - 1)x^2 + 1 - 2m. TH1: m = 0 hàm số luôn có một cực trị. TH2: m ≠ 0. y' = -4m x^3 + 4(m - 1)x. Để hàm số có một cực trị thì vô nghiệm hoặc có nghiệm kép bằng 0. Kết hợp cả hai trường hợp ta có 0 ≤ m ≤ 1."}
# ---------------------------------
#
#
# ------------------ADDED-------------------
# {'question': 'Giá trị của m để hàm số y = x^3 - 3mx^2 + (m^2 - 1)x + 2 đạt cực đại tại x = 2 là:', 'A': 'm = 1', 'B': 'm = 11', 'C': 'm = -1', 'D': 'Không tồn tại', 'answer': 'A', 'reasoning': "y' = 3x^2 - 6mx + m^2 - 1; y'' = 6x - 6m. Hàm số đạt cực đại tại x = 2 khi y'' < 0."}
# ---------------------------------
#
#
# ------------------ADDED-------------------
# {'question': 'Với giá trị nào của m, hàm số y = (x - m)^3 - 3x đạt cực tiểu tại điểm có hoành độ x = 0?', 'A': 'm = 1', 'B': 'm = -1', 'C': 'm = 0', 'D': 'Không tồn tại', 'answer': 'A', 'reasoning': "Xét y = x^3 - 3mx^2 + (3m^2 - 3)x - m^2. Ta có: y' = 3x^2 - 6mx + 3m^2 - 3, y'' = 6x - 6m. Hàm số đạt cực tiểu tại điểm có hoành độ x = 0 khi y'' > 0, tức là -6m > 0, hay m < 0. Vậy m = -1."}
# ---------------------------------
#
#
# ------------------ADDED-------------------
# {'question': 'Với giá trị nào của m, hàm số y = x^3 + 2(m - 1)x^2 + (m^2 - 4m + 1)x + 2(m^2 + 1) có hai điểm cực trị x_1, x_2 thỏa mãn', 'A': 'm = 1/2', 'B': 'm = 2', 'C': 'm = 1/2 hoặc m = 2', 'D': 'Không tồn tại', 'answer': 'A', 'reasoning': "Ta có y' = 3x^2 + 4(m - 1)x + m^2 - 4m + 1. Hàm số có hai cực trị => y' = 0 có hai nghiệm phân biệt <=> Δ' > 0 <=> 4(m - 1)^2 - 3(m^2 - 4m + 1) > 0 <=> m^2 + 4m + 1 > 0. Áp dụng Vi-ét cho phương trình y’ = 0 có hai nghiệm phân biệt x_1, x_2 ta có : Đối chiếu điều kiện (*) có m = 5 hoặc m = 1"}
# ---------------------------------
#
#
# ------------------ADDED-------------------
# {'question': 'Với giá trị nào của m, đồ thị hàm số y = x^3 - 3mx^2 + m có hai điểm cực trị B, C thẳng hàng với điểm A(-1;3)?', 'A': 'm = 0', 'B': 'm = 1', 'C': 'm = -3/2', 'D': 'm = -3/2 hoặc m = 1', 'answer': 'A', 'reasoning': 'y’= 3x^2 - 6mx = 3x(x - 2m). Hàm số có hai điểm cực trị => y’=0 có hai nghiệm phân biệt <=> m ≠ 0. Tọa độ hai điểm cực trị là B(0;m) và C(2m;-4m^3 + m). AB→ =(1;m – 3); AC→ =(2m+1; -4m^3 + m-3). A, B, C thẳng hàng.'}
# ---------------------------------
#
#
# ------------------ADDED-------------------
# {'question': 'Cho hàm số y = x^{3} - 3x^{2} - 6x + 8 (C). Phương trình đường thẳng đi qua hai điểm cực trị của đồ thị hàm số (C) là:', 'A': 'y = 6x - 6', 'B': 'y = -6x - 6', 'C': 'y = 6x + 6', 'D': 'y = -6x + 6', 'answer': 'A', 'reasoning': 'Ta có y’=3x^{2}-6x-6 ; y”=6x - 6. Do đó đồ thị hàm số có điểm cực trị là A(1 + √3; -6√3) và B(1 - √3; 6√3) . Phương trình đường thẳng đi qua hai điểm cực trị là: y = - 6x+6.'}
# ---------------------------------
#
#
# ------------------ADDED-------------------
# {'question': 'Cho hàm số y = x^3 -3x^2 - 9x + 4. Phương trình đường thẳng đi qua hai điểm cực trị của đồ thị hàm số trên là:', 'A': 'y = -8x + 1', 'B': 'y = x + 7', 'C': 'y = -x + 1', 'D': 'Không tồn tại', 'answer': 'A', 'reasoning': 'Do đồ thị hàm số có hai điểm cực trị là A(-1;9) và B(3;-23). Phương trình đường thẳng đi qua hai điểm cực trị là: y = -8x + 1'}
# ---------------------------------
#
#
# ------------------ADDED-------------------
# {'question': 'Với giá trị nào của m, đường thẳng đi qua hai điểm cực trị của đồ thị hàm số y = x^3 - 3x^2 + 3mx + 1 - m tạo với đường thẳng Δ: 3x + y - 8 = 0 một góc 45^o ?', 'A': 'm = 0', 'B': 'm = 2', 'C': 'm = 3/4', 'D': 'm = 2 hoặc m = 3/4', 'answer': 'C', 'reasoning': "Ta có y' = 3x^2 - 6x + 3m. Hàm số có hai điểm cực trị <=> y’=0 có hai nghiệm phân biệt <=> Δ' = 3^2 -3.3m > 0 <=> m < 1. Chia y cho y’ ta được: y= (2m-2)x+1. Vì góc giữa đường thẳng (d) và (Δ) là 45^o nên đối chiếu điều kiện (*) có m = 3/4"}
# ---------------------------------
#
#
# ------------------ADDED-------------------
# {'question': 'Với giá trị nào của m, đồ thị hàm số y = x^3 + 3x^2 + m^2x + m có hai điểm cực trị đối xứng qua đường thẳng:', 'A': 'm = 0', 'B': 'm = 1', 'C': 'm = -1', 'D': 'Không tồn tại', 'answer': 'D', 'reasoning': "y' = 3x^2 + 6x + m^2. Hàm số có hai điểm cực trị => y’=0 có hai nghiệm phân biệt <=> Δ' = 3^2 - 3.m^2 > 0 <=> -√3 < m < √3. Chia y cho y’ ta được: ... (detailed explanation omitted)"}
# ---------------------------------
#
#
# ------------------ADDED-------------------
# {'question': 'Với giá trị nào của m, đồ thị hàm số y = x^4 - 2mx^2 + m^4 + 2m có ba điểm cực trị tạo thành tam giác đều?', 'A': 'm = 0', 'B': 'm = \\sqrt[3]{3}', 'C': '-\\sqrt[3]{3}', 'D': 'Không tồn tại', 'answer': 'B', 'reasoning': "y' = 4x^3 - 4mx = 4x(x^2 - m). Hàm số có ba điểm cực trị => y’=0 có ba nghiệm phân biệt <=> m > 0. Khi đó đồ thị hàm số có ba điểm cực trị là : A(0; m^4 + 2m), B(-\\sqrt{m}; m^4 - m^2 + 2m), C(\\sqrt{m}; m^4 - m^2 + 2m). ΔABC đều khi AB=AC. Đối chiếu với điều kiện tồn tại cực trị ta có m = \\sqrt[3]{3} là giá trị cần tìm."}
# ---------------------------------
#
#
# Saved 10 questions to crawl_result/giaitich12/bai-tap-trac-nghiem-cuc-tri-cua-ham-so-phan-2.csv.
# Using model llama-3.1-8b-instant to crawl crawl_result/giaitich12/bai-tap-trac-nghiem-gia-tri-lon-nhat-va-nho-nhat-cua-ham-so-phan-1.csv
# Getting all questions from the given urls...
# Getting questions from https://vietjack.com/../bai-tap-trac-nghiem-giai-tich-12/bai-tap-trac-nghiem-gia-tri-lon-nhat-va-nho-nhat-cua-ham-so-phan-1.jsp...
# Error fetching question: list index out of range
# --------------ERROR-------------------
# Question tag: <p style="color:green;"><b>Câu 2:</b> Giá trị lớn nhất của hàm số</p>
# Choices tags: []
# ---------------------------------
#
#
# Error fetching question: list index out of range
# --------------ERROR-------------------
# Question tag: <p style="color:green;"><b>Câu 3:</b> Giá trị lớn nhất của hàm số y = x(5 - 2x)<sup>2</sup> trên [0; 3] là:</p>
# Choices tags: []
# ---------------------------------
#
#
# Error fetching question: list index out of range
# --------------ERROR-------------------
# Question tag: <p style="color:green;"><b>Câu 4:</b> Giá trị lớn nhất của hàm số</p>
# Choices tags: [<p>có đồ thị như hình bên là</p>, <p>A.	 3      B. 7</p>, <p>B.	-1     D. 4</p>]
# ---------------------------------
#
#
# Got 6 questions from https://vietjack.com/../bai-tap-trac-nghiem-giai-tich-12/bai-tap-trac-nghiem-gia-tri-lon-nhat-va-nho-nhat-cua-ham-so-phan-1.jsp.
# Reformatting all questions...
# ------------------ADDED-------------------
# {'question': 'Một công ti quản lí chuẩn bị xây dựng một khu chung cư mới. Họ tính toán nếu tòa nhà có x căn hộ thì chi phí bảo trì của tòa nhà là: C(x) = 4000 - 14x + 0,04x^2. Khu đất của họ có thể xây được tòa nhà chứa tối đa 300 căn hộ. Hỏi họ nên xây dựng tòa nhà có bao nhiêu căn hộ để chi phí bảo trì của tòa nhà là nhỏ nhất?', 'A': '150', 'B': '175', 'C': '300', 'D': '', 'answer': 'B', 'reasoning': 'C(x) đạt giá trị nhỏ nhất khi x = 175 vì C(0) = 4000; C(175) = 2775; C(300) = 3400'}
# ---------------------------------
#
#
# Error extracting or parsing JSON: Expecting value: line 1 column 1 (char 0)
# --------------ERROR-------------------
# Input string:
# ---------------------------------
#
#
# ------------------ADDED-------------------
# None
# ---------------------------------
